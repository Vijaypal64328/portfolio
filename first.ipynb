# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijaypal64328/portfolio/blob/main/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
a=10
b=20
print("sum =",a+b)
# Out:
# sum = 30
